# %%
# Standard setup for matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
# Make a figure, store it as fig
plt.plot(range(10))
fig = plt.gcf()   # gcf = get current figure

# %%
ax = fig.axes[0]

# %%
# Press tab at the end of this to see what you can modify
ax.set_
